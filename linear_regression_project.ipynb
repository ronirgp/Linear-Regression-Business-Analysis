# %% [markdown]
# # Linear Regression Business Analysis
#
# ## Project Goal
#
# The goal of this project is to predict business sales using advertising expenditure with a Linear Regression model built using Python and Scikit-Learn.
#
# ## Skills Demonstrated
#
# - Python
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-Learn
# - Data Visualization
# - Linear Regression
# - Business Analysis

# %%
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
# Out:
# NumPy: 2.5.0
# Pandas: 3.0.4

# %% [markdown]
# # Linear Regression Business Analysis
#
# ## 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("data/business_data.csv")

# %%
df.head()
# Out:
#          Date Region Product  Units  Price  Marketing_Spend
# 0  2024-01-01  North  Laptop      5   1200              500
# 1  2024-01-08  South   Phone     12    800              300
# 2  2024-01-15  North  Tablet      8    500              200
# 3  2024-01-22  South  Laptop      4   1200              450
# 4  2024-01-29  North   Phone     15    800              600

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             15 non-null     str
#  1   Region           15 non-null     str
#  2   Product          15 non-null     str
#  3   Units            15 non-null     int64
#  4   Price            15 non-null     int64
#  5   Marketing_Spend  15 non-null     int64
# dtypes: int64(3), str(3)
# memory usage: 852.0 bytes

# %%
df.describe()
# Out:
#            Units        Price  Marketing_Spend
# count  15.000000    15.000000        15.000000
# mean   11.200000   833.333333       465.333333
# std     5.479833   296.808420       201.418777
# min     4.000000   500.000000       200.000000
# 25%     7.500000   500.000000       280.000000
# 50%    10.000000   800.000000       500.000000
# 75%    14.000000  1200.000000       600.000000
# max    22.000000  1200.000000       800.000000

# %%
plt.scatter(df["Marketing_Spend"], df["Units"])

plt.xlabel("Marketing Spend")
plt.ylabel("Units Sold")
plt.title("Marketing Spend vs Units Sold")

plt.show()

# %%
X = df[["Marketing_Spend"]]
y = df["Units"]

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Intercept (b0):", model.intercept_)
print("Slope (b1):", model.coef_[0])
# Out:
# Intercept (b0): 4.347481102399174
# Slope (b1): 0.01472604347621954

# %%
comparison = df.copy()

comparison["Predicted_Units"] = predictions

print(comparison)
# Out:
#           Date Region Product  Units  Price  Marketing_Spend  Predicted_Units  \
# 0   2024-01-01  North  Laptop      5   1200              500        11.710503
# 1   2024-01-08  South   Phone     12    800              300         8.765294
# 2   2024-01-15  North  Tablet      8    500              200         7.292690
# 3   2024-01-22  South  Laptop      4   1200              450        10.974201
# 4   2024-01-29  North   Phone     15    800              600        13.183107
# 5   2024-02-05  South  Tablet     10    500              250         8.028992
# 6   2024-02-12  North  Laptop      6   1200              550        12.446805
# 7   2024-02-19  South   Phone     18    800              700        14.655712
# 8   2024-02-26  North  Tablet      9    500              220         7.587211
# 9   2024-03-05  South  Laptop      7   1200              500        11.710503
# 10  2024-03-12  North   Phone     20    800              750        15.392014
# ...

# %%
plt.scatter(df["Marketing_Spend"], df["Units"], color="blue", label="Actual Sales")

plt.plot(df["Marketing_Spend"], predictions,
         color="red",
         linewidth=2,
         label="Regression Line")

plt.xlabel("Marketing Spend")
plt.ylabel("Units Sold")
plt.title("Linear Regression Model")
plt.legend()

plt.show()

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y, predictions)

print("R² Score:", r2)
# Out:
# R² Score: 0.2929796090273554

# %%
comparison = df.copy()

comparison["Predicted_Units"] = predictions
comparison["Error"] = comparison["Units"] - comparison["Predicted_Units"]
comparison["Absolute_Error"] = comparison["Error"].abs()

comparison
# Out:
#           Date Region Product  Units  Price  Marketing_Spend  Predicted_Units  \
# 0   2024-01-01  North  Laptop      5   1200              500        11.710503
# 1   2024-01-08  South   Phone     12    800              300         8.765294
# 2   2024-01-15  North  Tablet      8    500              200         7.292690
# 3   2024-01-22  South  Laptop      4   1200              450        10.974201
# 4   2024-01-29  North   Phone     15    800              600        13.183107
# 5   2024-02-05  South  Tablet     10    500              250         8.028992
# 6   2024-02-12  North  Laptop      6   1200              550        12.446805
# 7   2024-02-19  South   Phone     18    800              700        14.655712
# 8   2024-02-26  North  Tablet      9    500              220         7.587211
# 9   2024-03-05  South  Laptop      7   1200              500        11.710503
# 10  2024-03-12  North   Phone     20    800              750        15.392014
# ...

# %%
comparison.to_csv("results/regression_results.csv", index=False)

print("Results saved successfully!")
# Out:
# Results saved successfully!

# %%
from sklearn.metrics import root_mean_squared_error, r2_score

rmse = root_mean_squared_error(y, predictions)
r2 = r2_score(y, predictions)

print("RMSE:", rmse)
print("R²:", r2)
# Out:
# RMSE: 4.451451990567421
# R²: 0.2929796090273554

# %%
with open("results/model_summary.txt", "w") as file:
    file.write("Linear Regression Business Analysis\n")
    file.write("=" * 40 + "\n\n")

    file.write(f"Intercept (b0): {model.intercept_:.4f}\n")
    file.write(f"Slope (b1): {model.coef_[0]:.4f}\n")
    file.write(f"RMSE: {rmse:.4f}\n")
    file.write(f"R² Score: {r2:.4f}\n\n")

    file.write("Model Description:\n")
    file.write("This model predicts Units Sold based on Marketing Spend.\n")
    file.write("The predictions are estimates and may differ from actual sales.\n")
    file.write("Adding more variables such as weather, holidays, region,\n")
    file.write("product type, and pricing could improve the model.\n")

print("Model summary saved successfully!")
# Out:
# Model summary saved successfully!

# %%
print(df.columns)
# Out:
# Index(['Date', 'Region', 'Product', 'Units', 'Price', 'Marketing_Spend'], dtype='str')

# %%
predictions = model.predict(X)

# %%
df["Predicted_Units"] = predictions

# %% [markdown]
# # Linear Regression Business Analysis
#
# ## Import Libraries
#
# ## Load Dataset
#
# ## Data Exploration
#
# ## Build the Model
#
# ## Predictions
#
# ## Residual Analysis
#
# ## SSE
#
# ## Business Conclusions

# %%
df["Error"] = df["Units"] - df["Predicted_Units"]

df["Squared_Error"] = df["Error"] ** 2

df[["Units",
    "Predicted_Units",
    "Error",
    "Squared_Error"]]
# Out:
#     Units  Predicted_Units     Error  Squared_Error
# 0       5        11.710503 -6.710503      45.030848
# 1      12         8.765294  3.234706      10.463322
# 2       8         7.292690  0.707310       0.500288
# 3       4        10.974201 -6.974201      48.639475
# 4      15        13.183107  1.816893       3.301099
# 5      10         8.028992  1.971008       3.884873
# 6       6        12.446805 -6.446805      41.561295
# 7      18        14.655712  3.344288      11.184265
# 8       9         7.587211  1.412789       1.995974
# 9       7        11.710503 -4.710503      22.188837
# 10     20        15.392014  4.607986      21.233538
# 11     11         8.176252  2.823748       7.973550
# 12      8        13.183107 -5.183107      26.864600
# 13     22        16.128316  5.871684      34.476674
# 14     13         8.765294  4.234706      17.932734

# %%
df[["Units", "Predicted_Units", "Error", "Squared_Error"]]
# Out:
#     Units  Predicted_Units     Error  Squared_Error
# 0       5        11.710503 -6.710503      45.030848
# 1      12         8.765294  3.234706      10.463322
# 2       8         7.292690  0.707310       0.500288
# 3       4        10.974201 -6.974201      48.639475
# 4      15        13.183107  1.816893       3.301099
# 5      10         8.028992  1.971008       3.884873
# 6       6        12.446805 -6.446805      41.561295
# 7      18        14.655712  3.344288      11.184265
# 8       9         7.587211  1.412789       1.995974
# 9       7        11.710503 -4.710503      22.188837
# 10     20        15.392014  4.607986      21.233538
# 11     11         8.176252  2.823748       7.973550
# 12      8        13.183107 -5.183107      26.864600
# 13     22        16.128316  5.871684      34.476674
# 14     13         8.765294  4.234706      17.932734

# %%
sse = df["Squared_Error"].sum()
print(f"SSE = {sse:.5f}")
# Out:
# SSE = 297.23137

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["Units"], df["Predicted_Units"], alpha=0.8)

plt.plot(
    [df["Units"].min(), df["Units"].max()],
    [df["Units"].min(), df["Units"].max()],
    color="red",
    linewidth=2,
    label="Perfect Prediction"
)

plt.xlabel("Actual Units Sold")
plt.ylabel("Predicted Units Sold")
plt.title("Actual vs Predicted Units Sold")
plt.legend()

# Save FIRST
plt.savefig("images/actual_vs_predicted.png", dpi=300, bbox_inches="tight")

# Then display
plt.show()

# %%
plt.savefig("images/actual_vs_predicted.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# # Business Conclusions
#
# ## Summary
#
# This project demonstrates how Linear Regression can be used to estimate future sales based on marketing expenditure.
#
# ### Key Findings
#
# - Marketing Spend has a positive relationship with Units Sold.
# - The model achieved an RMSE of approximately 4.45 units.
# - The model achieved an R² score of approximately 0.293.
# - The model provides useful estimates but leaves room for improvement.
#
# ### Recommendations
#
# - Collect more historical sales data.
# - Include additional variables such as weather, holidays, region, and product category.
# - Compare Linear Regression with Decision Tree Regression and Random Forest Regression to improve prediction accuracy.
